# %% [markdown]
# # Notebook 03: Stylometric Feature Extraction & Decay Analysis
# **Ship of Theseus — Computational Forensics Project**
#
# Extract **5+ Stylometric Features** T0 → T3 and generate at least one decay plot.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

ROOT = Path().resolve().parents[0]
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.utils.config import DATA_PROCESSED, DATASETS, STAGES, FAMILIES

FIGURES = ROOT / "figures" / "stylometry"
EXP_DATA = ROOT / "experiments" / "stylometry"
FIGURES.mkdir(parents=True, exist_ok=True)
EXP_DATA.mkdir(parents=True, exist_ok=True)

print(f"Project root: {ROOT}")
# Out:
# Project root: C:\Users\cnguy\Documents\CS6120\ShipOfTheseus-NLP

# %% [markdown]
# ## Load Chain Data
# Load T0 → T3 chains from `data/processed/`. Sample 500 rows per dataset for speed (spaCy parsing is slower than similarity metrics).

# %%
SAMPLE_N = 500
SEED = 42

chains = {}
for name in DATASETS.keys():
    path = DATA_PROCESSED / f"{name}_chains.csv"
    df = pd.read_csv(path)
    chains[name] = df.sample(min(SAMPLE_N, len(df)), random_state=SEED)
    print(f"Loaded '{name}': {chains[name].shape}")

print(f"\nColumns: {chains['wp'].columns.tolist()}")
# Out:
# Loaded 'sci_gen': (500, 8)
# Loaded 'wp': (500, 8)
# Loaded 'xsum': (500, 8)
# Loaded 'eli5': (500, 8)
# Loaded 'cmv': (500, 8)
# Loaded 'tldr': (500, 8)
# Loaded 'yelp': (500, 8)
#
# Columns: ['key', 'source', 'paraphraser', 'family', 'T0', 'T1', 'T2', 'T3']

# %% [markdown]
# ## Extract Stylometric Features (5+ Features)
#
# For each stage (T0 → T3), extract:
# 1. **Sentence length** (mean, variance)
# 2. **Type-Token Ratio (TTR)** — lexical diversity
# 3. **Punctuation ratio**
# 4. **POS tag frequencies** (NOUN, VERB, ADJ, ADV, etc.)
# 5. **Dependency tree depth** (mean, max)
#
# Uses spaCy `en_core_web_sm` for POS tagging and dependency parsing.

# %%
from src.features.stylometry import extract_features_batch, aggregate_features_by_stage

# Use a combined sample from all datasets for the main analysis
# Focus on 3 representative datasets to keep runtime manageable
FOCUS_DATASETS = ["wp", "xsum", "yelp"]

all_stage_features = {}

for name in FOCUS_DATASETS:
    print(f"\n{'='*60}")
    print(f"Dataset: {name}")
    print(f"{'='*60}")
    stage_feats, sampled = aggregate_features_by_stage(
        chains[name], stages=("T0", "T1", "T2", "T3"), sample_n=SAMPLE_N, seed=SEED
    )
    all_stage_features[name] = stage_feats

    # Save per-stage features
    for stage, feat_df in stage_feats.items():
        feat_df.to_csv(EXP_DATA / f"{name}_{stage}_features.csv", index=False)

print("\nFeature extraction complete!")
# Out:
# ============================================================
# Dataset: wp
# ============================================================
#
# Extracting features for T0...
#   Processed 100/500 texts
#   Processed 200/500 texts
#   Processed 300/500 texts
#   Processed 400/500 texts
#   Processed 500/500 texts
#   Done: 500/500 texts
#
# Extracting features for T1...
#   Processed 100/500 texts
#   Processed 200/500 texts
#   Processed 300/500 texts
#   Processed 400/500 texts
#   Processed 500/500 texts
#   Done: 500/500 texts
#
# Extracting features for T2...
#   Processed 100/499 texts
#   Processed 200/499 texts
#   Processed 300/499 texts
#   Processed 400/499 texts
#   Done: 499/499 texts
#
# Extracting features for T3...
#   Processed 100/498 texts
#   Processed 200/498 texts
#   Processed 300/498 texts
#   Processed 400/498 texts
#   Done: 498/498 texts
#
# ============================================================
# Dataset: xsum
# ============================================================
#
# Extracting features for T0...
#   Processed 100/500 texts
#   Processed 200/500 texts
#   Processed 300/500 texts
#   Processed 400/500 texts
#   Processed 500/500 texts
#   Done: 500/500 texts
#
# Extracting features for T1...
#   Processed 100/500 texts
#   Processed 200/500 texts
#   Processed 300/500 texts
#   Processed 400/500 texts
#   Processed 500/500 texts
#   Done: 500/500 texts
#
# Extracting features for T2...
#   Processed 100/498 texts
#   Processed 200/498 texts
#   Processed 300/498 texts
#   Processed 400/498 texts
#   Done: 498/498 texts
#
# Extracting features for T3...
#   Processed 100/498 texts
#   Processed 200/498 texts
#   Processed 300/498 texts
#   Processed 400/498 texts
#   Done: 498/498 texts
#
# ============================================================
# Dataset: yelp
# ============================================================
#
# Extracting features for T0...
#   Processed 100/500 texts
#   Processed 200/500 texts
#   Processed 300/500 texts
#   Processed 400/500 texts
#   Processed 500/500 texts
#   Done: 500/500 texts
#
# Extracting features for T1...
#   Processed 100/500 texts
#   Processed 200/500 texts
#   Processed 300/500 texts
#   Processed 400/500 texts
#   Processed 500/500 texts
#   Done: 500/500 texts
#
# Extracting features for T2...
#   Processed 100/500 texts
#   Processed 200/500 texts
#   Processed 300/500 texts
#   Processed 400/500 texts
#   Processed 500/500 texts
#   Done: 500/500 texts
#
# Extracting features for T3...
#   Processed 100/500 texts
#   Processed 200/500 texts
#   Processed 300/500 texts
#   Processed 400/500 texts
#   Processed 500/500 texts
#   Done: 500/500 texts
#
# Feature extraction complete!

# %% [markdown]
# ## Feature Summary Table by Stage
# Mean values of each stylometric feature across T0 → T3, aggregated across all focus datasets.

# %%
SCALAR_FEATURES = ["sent_len_mean", "sent_len_var", "ttr", "punct_ratio",
                    "dep_depth_mean", "dep_depth_max"]

# Build summary table: mean of each feature per stage (across all datasets)
summary_rows = []
for stage in STAGES:
    combined = pd.concat([all_stage_features[name][stage] for name in FOCUS_DATASETS],
                         ignore_index=True)
    row = {"stage": stage}
    for feat in SCALAR_FEATURES:
        row[feat] = combined[feat].mean()
    summary_rows.append(row)

summary_df = pd.DataFrame(summary_rows).set_index("stage").round(4)
print("Mean Stylometric Features by Stage (across all focus datasets):")
print(summary_df.to_string())
summary_df.to_csv(EXP_DATA / "feature_summary_by_stage.csv")
# Out:
# Mean Stylometric Features by Stage (across all focus datasets):
#        sent_len_mean  sent_len_var     ttr  punct_ratio  dep_depth_mean  dep_depth_max
# stage
# T0           16.8545       92.6364  0.6315       0.0332          2.6223         8.6787
# T1           17.1594      101.9358  0.6309       0.0305          2.5796         8.3307
# T2           16.9291       91.0270  0.6437       0.0305          2.5472         8.2472
# T3           16.6036       94.9926  0.6540       0.0309          2.5178         7.9672

# %% [markdown]
# ---
# ## Figure 1: Stylometric Feature Decay Curves (T0 → T3)
# Normalize each feature to its T0 value and plot the decay. This shows which "planks" are replaced fastest.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# --- Left panel: Absolute feature values ---
ax = axes[0]
colors = {'sent_len_mean': '#1565C0', 'ttr': '#E53935', 'dep_depth_mean': '#2E7D32',
          'punct_ratio': '#FF8F00', 'sent_len_var': '#7B1FA2', 'dep_depth_max': '#00838F'}
markers = {'sent_len_mean': 'o', 'ttr': 's', 'dep_depth_mean': '^',
           'punct_ratio': 'D', 'sent_len_var': 'v', 'dep_depth_max': 'P'}

for feat in SCALAR_FEATURES:
    vals = [summary_df.loc[s, feat] for s in STAGES]
    ax.plot(STAGES, vals, marker=markers[feat], color=colors[feat],
            linewidth=2, markersize=7, label=feat)
ax.set_title("Stylometric Features Across Stages", fontweight='bold')
ax.set_xlabel("Paraphrase Stage")
ax.set_ylabel("Feature Value")
ax.legend(fontsize=8, loc='best')
ax.grid(alpha=0.3)

# --- Right panel: Normalized to T0 = 1.0 ---
ax = axes[1]
for feat in SCALAR_FEATURES:
    t0_val = summary_df.loc["T0", feat]
    if t0_val == 0:
        continue
    normed = [summary_df.loc[s, feat] / t0_val for s in STAGES]
    ax.plot(STAGES, normed, marker=markers[feat], color=colors[feat],
            linewidth=2, markersize=7, label=feat)
ax.axhline(1.0, color='grey', linestyle='--', alpha=0.5)
ax.set_title("Normalized Feature Decay (T0 = 1.0)", fontweight='bold')
ax.set_xlabel("Paraphrase Stage")
ax.set_ylabel("Relative to T0")
ax.legend(fontsize=8, loc='best')
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(FIGURES / "fig1_feature_decay_curves.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: fig1_feature_decay_curves.png")
# Out:
# Saved: fig1_feature_decay_curves.png

# %%
fig, ax = plt.subplots(1, figsize=(8, 5))
for feat in SCALAR_FEATURES:
    t0_val = summary_df.loc["T0", feat]
    if t0_val == 0:
        continue
    normed = [summary_df.loc[s, feat] / t0_val for s in STAGES]
    ax.plot(STAGES, normed, marker=markers[feat], color=colors[feat],
            linewidth=2, markersize=7, label=feat)

    ax.annotate(f"{normed[-1]:.2f}",
                xy=("T3", normed[-1]),
                xytext=(6, 0), textcoords='offset points',
                fontsize=7.5, fontweight='bold', color=colors[feat], va='center')
    
ax.axhline(1.0, color='grey', linestyle='--', alpha=0.5)
ax.set_title("Normalized Feature Decay (T0 = 1.0)", fontweight='bold')
ax.set_xlabel("Paraphrase Stage")
ax.set_ylabel("Relative to T0")
ax.legend(fontsize=8, loc='best')
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(FIGURES / "fig1.1_normalized_feature_decay_curves.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: fig1_feature_decay_curves.png")
# Out:
# Saved: fig1_feature_decay_curves.png

# %% [markdown]
# ## Figure 2: POS Tag Frequency Heatmap (T0 vs T3)
# Compare how part-of-speech distributions shift from the original human text (T0) to the 3rd-generation paraphrase (T3).

# %%
from src.features.stylometry import TRACKED_POS

pos_cols = [f"pos_{p}" for p in TRACKED_POS]
# Filter to POS tags that have meaningful frequency (> 0.01 on average)
MAIN_POS = ["NOUN", "VERB", "ADJ", "ADV", "PRON", "DET", "ADP", "PUNCT"]
main_pos_cols = [f"pos_{p}" for p in MAIN_POS]

# Build heatmap data: rows = POS tags, columns = stages
heatmap_data = {}
for stage in STAGES:
    combined = pd.concat([all_stage_features[name][stage] for name in FOCUS_DATASETS],
                         ignore_index=True)
    heatmap_data[stage] = combined[main_pos_cols].mean()

heatmap_df = pd.DataFrame(heatmap_data).round(4)
heatmap_df.index = MAIN_POS

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Left: Absolute POS frequencies
ax = axes[0]
sns.heatmap(heatmap_df, annot=True, fmt=".3f", cmap="YlOrRd", ax=ax,
            linewidths=0.5, cbar_kws={'label': 'Frequency'})
ax.set_title("POS Tag Frequencies by Stage", fontweight='bold')
ax.set_ylabel("POS Tag")
ax.set_xlabel("Paraphrase Stage")

# Right: Change from T0 (delta)
ax = axes[1]
delta_df = heatmap_df.subtract(heatmap_df["T0"], axis=0)
sns.heatmap(delta_df, annot=True, fmt=".4f", cmap="RdBu_r", center=0, ax=ax,
            linewidths=0.5, cbar_kws={'label': 'Change from T0'})
ax.set_title("POS Frequency Change from T0", fontweight='bold')
ax.set_ylabel("POS Tag")
ax.set_xlabel("Paraphrase Stage")

plt.tight_layout()
plt.savefig(FIGURES / "fig2_pos_heatmap.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: fig2_pos_heatmap.png")
# Out:
# Saved: fig2_pos_heatmap.png

# %% [markdown]
# ## Figure 3: Dependency Depth Distribution (T0 vs T3)
# Box plots showing how syntactic complexity (dependency tree depth) changes across paraphrase iterations.

# %%
# Build long-form dataframe for boxplots
dep_rows = []
for stage in STAGES:
    combined = pd.concat([all_stage_features[name][stage] for name in FOCUS_DATASETS],
                         ignore_index=True)
    for _, row in combined.iterrows():
        dep_rows.append({"stage": stage, "dep_depth_mean": row["dep_depth_mean"],
                         "dep_depth_max": row["dep_depth_max"],
                         "sent_len_var": row["sent_len_var"],
                         "ttr": row["ttr"]})
dep_long = pd.DataFrame(dep_rows)

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

# Dependency depth (mean)
sns.boxplot(data=dep_long, x="stage", y="dep_depth_mean", ax=axes[0],
            palette="Blues", order=STAGES)
axes[0].set_title("Mean Dependency Depth by Stage", fontweight='bold')
axes[0].set_xlabel("Paraphrase Stage")
axes[0].set_ylabel("Mean Dependency Depth")

# TTR
sns.boxplot(data=dep_long, x="stage", y="ttr", ax=axes[1],
            palette="Reds", order=STAGES)
axes[1].set_title("Type-Token Ratio by Stage", fontweight='bold')
axes[1].set_xlabel("Paraphrase Stage")
axes[1].set_ylabel("TTR (Lexical Diversity)")

# Sentence length variance
sns.boxplot(data=dep_long, x="stage", y="sent_len_var", ax=axes[2],
            palette="Greens", order=STAGES)
axes[2].set_title("Sentence Length Variance by Stage", fontweight='bold')
axes[2].set_xlabel("Paraphrase Stage")
axes[2].set_ylabel("Variance (words)")

plt.tight_layout()
plt.savefig(FIGURES / "fig3_dep_depth_boxplots.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: fig3_dep_depth_boxplots.png")
# Out:
# C:\Users\cnguy\AppData\Local\Temp\ipykernel_17476\4047332752.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dep_long, x="stage", y="dep_depth_mean", ax=axes[0],
# C:\Users\cnguy\AppData\Local\Temp\ipykernel_17476\4047332752.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dep_long, x="stage", y="ttr", ax=axes[1],
# C:\Users\cnguy\AppData\Local\Temp\ipykernel_17476\4047332752.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dep_long, x="stage", y="sent_len_var", ax=axes[2],
# Saved: fig3_dep_depth_boxplots.png

# %% [markdown]
# ## Figure 4: POS Distribution Jensen-Shannon Divergence (T0 vs Tn)
# Quantifies how far the POS distribution at each stage has drifted from the original T0.

# %%
from src.features.stylometry import compute_pos_divergence

fig, ax = plt.subplots(figsize=(8, 5))

for name in FOCUS_DATASETS:
    # Get mean POS distribution per stage
    t0_mean = all_stage_features[name]["T0"][main_pos_cols].mean().to_dict()
    js_vals = [0.0]  # T0 vs T0 = 0
    for stage in ["T1", "T2", "T3"]:
        tn_mean = all_stage_features[name][stage][main_pos_cols].mean().to_dict()
        js_vals.append(compute_pos_divergence(t0_mean, tn_mean))

    ax.plot(STAGES, js_vals, marker='o', linewidth=2, markersize=8, label=name)

ax.set_title("POS Distribution Drift from T0\n(Jensen-Shannon Divergence)", fontweight='bold')
ax.set_xlabel("Paraphrase Stage")
ax.set_ylabel("JS Divergence (0=identical, 1=max)")
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(FIGURES / "fig4_pos_js_divergence.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: fig4_pos_js_divergence.png")
# Out:
# Saved: fig4_pos_js_divergence.png

# %% [markdown]
# ---
# ## Figure 5: Human vs. AI Source — POS Drift Comparison
#
# **Question:** When paraphrasers rewrite human-authored T0 vs. AI-authored T0 texts,
# does the style change differ?
#
# - **Human T0** → paraphrased → does the style change more? (human writing has unique style)
# - **AI T0** → paraphrased → does the style change less? (already AI-like)
#
# We compute POS cosine similarity (T0 vs T1) grouped by source type across all 7 datasets.

# %%
import spacy
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity

nlp_pos = spacy.load('en_core_web_sm', disable=['ner', 'lemmatizer'])

UPOS_TAGS = [
    'ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN',
    'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB', 'X'
]

def pos_vector_batch(texts, batch_size=500):
    """Compute POS frequency vectors for a list of texts using nlp.pipe()."""
    clean = [str(t)[:5000] if isinstance(t, str) and t.strip() else "" for t in texts]
    vectors = []
    for doc in nlp_pos.pipe(clean, batch_size=batch_size):
        counts = Counter(t.pos_ for t in doc)
        total = sum(counts.values())
        if total == 0:
            vectors.append(np.zeros(len(UPOS_TAGS)))
        else:
            vectors.append(np.array([counts.get(tag, 0) / total for tag in UPOS_TAGS]))
    return vectors

# Load ALL 7 datasets for this analysis (source column needed)
all_chains = pd.concat(chains.values(), ignore_index=True)
all_chains['dataset'] = np.concatenate([[name] * len(chains[name]) for name in chains])
all_chains['source_group'] = all_chains['source'].apply(lambda s: 'Human' if s == 'Human' else 'LLM')

print(f"Total chains: {len(all_chains)}")
print(f"Source groups: {all_chains['source_group'].value_counts().to_dict()}")

# Compute POS vectors for T0 and T1
print("\nComputing POS vectors for T0...")
all_chains['pos_T0'] = pos_vector_batch(all_chains['T0'].tolist())
print("Computing POS vectors for T1...")
all_chains['pos_T1'] = pos_vector_batch(all_chains['T1'].tolist())

# Compute POS cosine similarity (T0 vs T1) per row — vectorized
v0 = np.vstack(all_chains['pos_T0'].values)
v1 = np.vstack(all_chains['pos_T1'].values)
dot = (v0 * v1).sum(axis=1)
norm0 = np.linalg.norm(v0, axis=1)
norm1 = np.linalg.norm(v1, axis=1)
denom = norm0 * norm1
all_chains['pos_cos_T1'] = np.where(denom > 0, dot / denom, np.nan)

print("Done.")
# Out:
# Total chains: 3500
# Source groups: {'LLM': 2961, 'Human': 539}
#
# Computing POS vectors for T0...
# Computing POS vectors for T1...
# Done.

# %%
# Aggregate by source_group x paraphraser x dataset
records = []
for ds in DATASETS.keys():
    ds_df = all_chains[all_chains['dataset'] == ds]
    for group in ['Human', 'LLM']:
        grp_df = ds_df[ds_df['source_group'] == group]
        if len(grp_df) == 0:
            continue
        for para in grp_df['paraphraser'].unique():
            para_df = grp_df[grp_df['paraphraser'] == para]
            records.append({
                'Dataset': ds,
                'Source': group,
                'Paraphraser': para,
                'Family': para_df['family'].iloc[0],
                'POS_Cosine_Mean': para_df['pos_cos_T1'].mean(),
                'POS_Cosine_Std': para_df['pos_cos_T1'].std(),
                'N': len(para_df),
            })

source_results = pd.DataFrame(records)

# Summary: Human vs LLM overall
print("=== POS Cosine Similarity (T0 vs T1) by Source Group ===\n")
for group in ['Human', 'LLM']:
    grp = all_chains[all_chains['source_group'] == group]
    print(f"  {group:6s}: mean={grp['pos_cos_T1'].mean():.4f}, std={grp['pos_cos_T1'].std():.4f}, n={len(grp)}")

# By paraphraser
print("\n=== By Paraphraser ===")
for para in sorted(source_results['Paraphraser'].unique()):
    for group in ['Human', 'LLM']:
        sub = source_results[(source_results['Paraphraser'] == para) & (source_results['Source'] == group)]
        if len(sub) > 0:
            mean_val = sub['POS_Cosine_Mean'].mean()
            print(f"  {para:18s} | {group:6s}: {mean_val:.4f}")

source_results.to_csv(EXP_DATA / "human_vs_llm_pos_cosine.csv", index=False)
# Out:
# === POS Cosine Similarity (T0 vs T1) by Source Group ===
#
#   Human : mean=0.9639, std=0.0737, n=539
#   LLM   : mean=0.9606, std=0.0682, n=2961
#
# === By Paraphraser ===
#   chatgpt            | Human : 0.9749
#   chatgpt            | LLM   : 0.9639
#   dipper             | Human : 0.9726
#   dipper             | LLM   : 0.9667
#   dipper(high)       | Human : 0.9056
#   dipper(high)       | LLM   : 0.8789
#   dipper(low)        | Human : 0.9883
#   dipper(low)        | LLM   : 0.9856
#   palm               | Human : 0.9711
#   palm               | LLM   : 0.9705
#   pegasus(full)      | Human : 0.9445
#   pegasus(full)      | LLM   : 0.9659
#   pegasus(slight)    | Human : 0.9898
#   pegasus(slight)    | LLM   : 0.9903

# %%
# Figure 5: Grouped bar chart — Human vs LLM POS cosine by paraphraser
fig, ax = plt.subplots(figsize=(10, 6))

# Select key paraphrasers for clarity
key_paras = ['chatgpt', 'dipper(high)', 'dipper(low)', 'pegasus(slight)', 'pegasus(full)', 'palm']
groups = ['Human', 'LLM']
bar_colors = {'Human': '#4C72B0', 'LLM': '#DD8452'}
x = np.arange(len(key_paras))
width = 0.35

for i, group in enumerate(groups):
    means = []
    for para in key_paras:
        sub = all_chains[(all_chains['paraphraser'] == para) & (all_chains['source_group'] == group)]
        means.append(sub['pos_cos_T1'].mean() if len(sub) > 0 else 0)
    offset = (i - 0.5) * width
    bars = ax.bar(x + offset, means, width, label=f'{group} T0', color=bar_colors[group],
                  edgecolor='black', linewidth=0.5)

ax.set_xlabel('Paraphraser', fontsize=12)
ax.set_ylabel('POS Cosine Similarity (T0 vs T1)', fontsize=12)
ax.set_title('Style Drift: Human-Authored vs AI-Authored Originals\n(Higher = less style change)',
             fontsize=13, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(key_paras, rotation=25, ha='right')
ax.set_ylim(0.85, 1.0)
ax.legend(fontsize=11)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig(FIGURES / "fig5_human_vs_llm_pos_drift.png", dpi=150, bbox_inches='tight')
plt.show()
print("Saved: fig5_human_vs_llm_pos_drift.png")
# Out:
# Saved: fig5_human_vs_llm_pos_drift.png
